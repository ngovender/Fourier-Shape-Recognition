# %% [markdown]
# <a href="https://colab.research.google.com/github/ngovender/Fourier-Shape-Recognition/blob/master/HeartDieaseDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/ngovender/heartDiease.git
# Out:
# Cloning into 'heartDiease'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (5/5), done.

# %%
import pandas as pd

X_Train = pd.read_csv('heartDiease/test_values.csv')
print(X_Train)
# Out:
#    patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0      olalu7                                  2  reversible_defect
# 1      z9n6mx                                  1             normal
# 2      5k4413                                  2  reversible_defect
# 3      mrg7q5                                  1             normal
# 4      uki4do                                  2             normal
# 5      kev1sk                                  2             normal
# 6      9n6let                                  3             normal
# 7      jxmtyg                                  2  reversible_defect
# 8      51s2ff                                  1             normal
# 9      wi9mcs                                  1             normal
# 10     741h4l                                  3             normal
# 11     1ef64a                                  2  reversible_defect
# 12     wa2ix6                                  1             normal
# ...

# %%
ls sample_data

# %%
# Out:
# test_values.csv  train_labels.csv  train_values.csv
